# %%
pip install qiskit qiskit-nature qiskit-algorithms pyscf
# Out:
# Requirement already satisfied: qiskit in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.0)
# Collecting qiskit-nature
#   Downloading qiskit_nature-0.7.2-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: qiskit-algorithms in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (0.4.0)
# Collecting pyscf
#   Downloading pyscf-2.12.0-py3-none-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: rustworkx>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (2.4.1)
# Requirement already satisfied: scipy>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: psutil>=5 in /Users/patrykksiazek/Library/Python/3.13/lib/python/site-packages (from qiskit-nature) (7.2.1)
# Requirement already satisfied: setuptools>=40.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit-nature) (80.10.2)
# Collecting h5py (from qiskit-nature)
#   Downloading h5py-3.15.1-cp313-cp313-macosx_10_13_x86_64.whl.metadata (3.0 kB)
# Downloading qiskit_nature-0.7.2-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 9.6 MB/s  0:00:00 eta 0:00:01
# Downloading pyscf-2.12.0-py3-none-macosx_10_9_x86_64.whl (36.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.0/36.0 MB 5.9 MB/s  0:00:06m0:00:0100:01
# Downloading h5py-3.15.1-cp313-cp313-macosx_10_13_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 6.2 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: h5py, pyscf, qiskit-nature
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [qiskit-nature]0m [qiskit-nature]
# Successfully installed h5py-3.15.1 pyscf-2.12.0 qiskit-nature-0.7.2
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Simulating a Quantum Chemistry Problem using Qiskit

# Simulate the hydrogen (H2) molecule using Qiskit's Quantum Chemistry module.
# Install Required Packages
# Import Required Libraries
# Define the Hydrogen Molecule
# Solve Using Variational Quantum Eigensolver (VQE)

# %%
import numpy as np
from qiskit_nature.second_q.problems import ElectronicStructureProblem
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.transformers import FreezeCoreTransformer
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_algorithms import VQE
from qiskit.circuit.library import TwoLocal
from qiskit_algorithms.optimizers import COBYLA
from qiskit.primitives import Estimator

# %%
# Define molecule (H2) geometry

molecule_geomtery = "H 0 0 0 ; H 0 0 0.735"  # 0.735 Angstroms apart
