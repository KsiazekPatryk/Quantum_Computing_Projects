# %%
pip install --upgrade qiskit qiskit-finance numpy pandas matplotlib
# Out:
# Requirement already satisfied: qiskit in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.0)
# Collecting qiskit-finance
#   Downloading qiskit_finance-0.4.1-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.4.1)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.3.3)
# Collecting pandas
#   Downloading pandas-3.0.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: rustworkx>=0.15.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (1.16.3)
# Requirement already satisfied: dill>=0.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (0.4.0)
# Requirement already satisfied: stevedore>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit) (4.15.0)
# Requirement already satisfied: qiskit-algorithms>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit-finance) (0.4.0)
# Collecting qiskit-optimization>=0.6.0 (from qiskit-finance)
#   Downloading qiskit_optimization-0.7.0-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: psutil>=5 in /Users/patrykksiazek/Library/Python/3.13/lib/python/site-packages (from qiskit-finance) (7.2.1)
# Collecting fastdtw (from qiskit-finance)
#   Downloading fastdtw-0.3.4.tar.gz (133 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: setuptools>=40.1.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit-finance) (80.10.2)
# Collecting nasdaq-data-link (from qiskit-finance)
#   Downloading Nasdaq_Data_Link-1.0.4-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting yfinance>=0.1.70 (from qiskit-finance)
#   Downloading yfinance-1.1.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit-finance) (2025.11.12)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit-finance) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting docplex!=2.24.231,>=2.21.207 (from qiskit-optimization>=0.6.0->qiskit-finance)
#   Downloading docplex-2.31.254.tar.gz (647 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.4/647.4 kB 3.7 MB/s  0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: networkx>=2.6.3 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from qiskit-optimization>=0.6.0->qiskit-finance) (3.5)
# Requirement already satisfied: requests>=2.31 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from yfinance>=0.1.70->qiskit-finance) (2.32.5)
# Collecting multitasking>=0.0.7 (from yfinance>=0.1.70->qiskit-finance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: platformdirs>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from yfinance>=0.1.70->qiskit-finance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from yfinance>=0.1.70->qiskit-finance) (2025.2)
# Collecting frozendict>=2.3.4 (from yfinance>=0.1.70->qiskit-finance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance>=0.1.70->qiskit-finance)
#   Downloading peewee-3.19.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from yfinance>=0.1.70->qiskit-finance) (4.14.2)
# Collecting curl_cffi<0.14,>=0.7 (from yfinance>=0.1.70->qiskit-finance)
#   Downloading curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl.metadata (13 kB)
# Collecting protobuf>=3.19.0 (from yfinance>=0.1.70->qiskit-finance)
#   Downloading protobuf-6.33.4-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting websockets>=13.0 (from yfinance>=0.1.70->qiskit-finance)
#   Downloading websockets-16.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (6.8 kB)
# Collecting cffi>=1.12.0 (from curl_cffi<0.14,>=0.7->yfinance>=0.1.70->qiskit-finance)
#   Downloading cffi-2.0.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->qiskit-finance) (2.8)
# Collecting pycparser (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance>=0.1.70->qiskit-finance)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.31->yfinance>=0.1.70->qiskit-finance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from requests>=2.31->yfinance>=0.1.70->qiskit-finance) (3.11)
# Collecting inflection>=0.3.1 (from nasdaq-data-link->qiskit-finance)
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting more-itertools (from nasdaq-data-link->qiskit-finance)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Downloading qiskit_finance-0.4.1-py3-none-any.whl (51 kB)
# Downloading pandas-3.0.0-cp313-cp313-macosx_10_13_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 7.5 MB/s  0:00:01eta 0:00:01
# Downloading qiskit_optimization-0.7.0-py3-none-any.whl (237 kB)
# Downloading yfinance-1.1.0-py2.py3-none-any.whl (129 kB)
# Downloading curl_cffi-0.13.0-cp39-abi3-macosx_10_9_x86_64.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 10.3 MB/s  0:00:00 eta 0:00:01
# Downloading cffi-2.0.0-cp313-cp313-macosx_10_13_x86_64.whl (185 kB)
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading peewee-3.19.0-py3-none-any.whl (411 kB)
# Downloading protobuf-6.33.4-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Downloading websockets-16.0-cp313-cp313-macosx_10_13_x86_64.whl (175 kB)
# Downloading Nasdaq_Data_Link-1.0.4-py2.py3-none-any.whl (28 kB)
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
# Building wheels for collected packages: docplex, multitasking, fastdtw
#   Building wheel for docplex (pyproject.toml) ... done
#   Created wheel for docplex: filename=docplex-2.31.254-py3-none-any.whl size=686240 sha256=d913dcfb5576795878749822f28cb69f68602de3b2b5a3615e3036ad0a977f7d
#   Stored in directory: /Users/patrykksiazek/Library/Caches/pip/wheels/86/be/35/921980e517ddc5cae61908142b5968fc0b931316f8b334ae6f
#   Building wheel for multitasking (pyproject.toml) ... done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15637 sha256=522db6ae31c658b98cf00b474cae01b4cc5f4bcd980703a3725d7ef3c8433f24
#   Stored in directory: /Users/patrykksiazek/Library/Caches/pip/wheels/1e/df/0f/e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
#   Building wheel for fastdtw (pyproject.toml) ... done
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-py3-none-any.whl size=3610 sha256=f294554f5892e5477199c79d82f98010398485417064a3788ceae856547c173f
#   Stored in directory: /Users/patrykksiazek/Library/Caches/pip/wheels/2c/9e/6d/6c419b5fe1b720cf2f9c7b20ea119dc201878ea890ba26221f
# Successfully built docplex multitasking fastdtw
# Installing collected packages: peewee, multitasking, websockets, pycparser, protobuf, more-itertools, inflection, frozendict, fastdtw, docplex, pandas, cffi, qiskit-optimization, nasdaq-data-link, curl_cffi, yfinance, qiskit-finance
#   Attempting uninstall: pandas╺━━━━━━━━━━━━━━━━━━  9/17 [docplex]]]
#     Found existing installation: pandas 2.3.3━━━━━━━━━━━━━━━━━  9/17 [docplex]
#     Uninstalling pandas-2.3.3:━╸━━━━━━━━━━━━━━━━ 10/17 [pandas]
#       Successfully uninstalled pandas-2.3.390m━━━━━━━━━━━━━━━━ 10/17 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17/17 [qiskit-finance]m [yfinance]]imization]
# Successfully installed cffi-2.0.0 curl_cffi-0.13.0 docplex-2.31.254 fastdtw-0.3.4 frozendict-2.4.7 inflection-0.5.1 more-itertools-10.8.0 multitasking-0.0.12 nasdaq-data-link-1.0.4 pandas-3.0.0 peewee-3.19.0 protobuf-6.33.4 pycparser-3.0 qiskit-finance-0.4.1 qiskit-optimization-0.7.0 websockets-16.0 yfinance-1.1.0
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Implement AI-QC Optimization for Portfolio Management
    #Install Required Libraries
    #Import Required Libraries
    #Generate Synthetic Financial Data
    #Define Portoflio Optimization Problem
    #Solve Using Variantional Quantum Eigensolver (VQE)

# %%
import numpy as np
import pandas as pdx
import matplotlib.pyplot as plt
from datetime import datetime
from qiskit_finance.data_providers import RandomDataProvider
from qiskit_finance.applications.optimization import PortfolioOptimization
from qiskit_optimization.algorithms import MinimumEigenOptimizer
from qiskit.primitives import Sampler
from qiskit.circuits.library import TwoLocal
from qiskit_algorithms import SamplingVQE
from qiskit_algorithms.optimizers import COBYLA
