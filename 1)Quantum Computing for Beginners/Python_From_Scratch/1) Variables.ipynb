# %%
5+6

# %%
1500 + 494

# %%
900/7

# %%
500 - 200

# %%
30 * 4

# %%
2 * 2 * 2

# %%
2 ** 3

# %%
2 ** 9

# %%
10 % 2

# %%
11 % 2

# %%
11%3

# %%
0.5 * 3

# %% [markdown]
# INTEGER

# %%
3 + 3

# %%
3 + 5

# %% [markdown]
# Float

# %% [markdown]
# 0.4 * 3.0

# %%
3 + 5

# %% [markdown]
# Variables

# %%
x = 3

# %%
y = 5

# %%
x+y

# %%
x**y

# %%
x = 4

# %%
x + y

# %%
r = input("r:")

# %%
type (x)

# %%
pi = 3.14

# %%
type(pi)

# %%
r

# %%
type(r)

# %%
x * pi

# %%
r_int = int(r)

# %%
r_int

# %%
r_int * pi * 2
