# %%
number = 10

def multiply(num):
    number = 5
    return num * number

# %%
multiply(10)

# %%
print(number)

# %%
a = 10
a = 5

# %%
print(a)

# %% [markdown]
# LEGB
#
# L -> Local
# E -> Enclosing
# G -> Global
# B -> Built-in

# %%
my_string = "Atil"
#Global

def my_func():
    my_string = "James"
    #Enclosing

    def my_func_2():

        #Local
        my_string = "Lars"
        print(my_string)
    
    my_func_2()
