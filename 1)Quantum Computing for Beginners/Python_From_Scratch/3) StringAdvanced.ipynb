# %%
my_string = "hello world"

# %%
my_string
# Out:
# 'hello world'

# %% [markdown]
# Indexing

# %%
my_string[0]
# Out:
# 'h'

# %%
my_string[4]
# Out:
# 'o'

# %%
my_string[-1]
# Out:
# 'd'

# %%
my_string[-2]
# Out:
# 'l'

# %%
my_string_2 = "1234567890"

# %%
my_string_2[0]
# Out:
# '1'

# %%
my_string_2[2:]
# Out:
# '34567890'

# %% [markdown]
# Slicing

# %%
my_string_2[4:]
# Out:
# '567890'

# %%
my_string_2[:2]

# %% [markdown]
# Stopping Index

# %%
my_string_2[:4]

# %%
my_string_2[2:4]

# %%
my_string_2[5:8]
