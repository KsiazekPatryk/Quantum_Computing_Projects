# %%
my_directory = {"key": "values"}

# %%
my_directory [key]

# %%
my_list = [100,200]

# %%
my_list_2 = ["run", "swim"]

# %%
my_list [0]

# %%
my_list_2 [0]

# %%
my_fitness_dicitionary = {"run": 100, "swim": 200}

# %%
my_fitness_dicitionary["run"]

# %%
my_fitness_dicitionary["swim"]

# %%
my_dictionary_2 = {"key1":1 , "key2":2, "key3":"apple"}

# %%
my_dictionary_2["key1"]

# %%
my_dictionary_2["key3"]

# %%
my_dictionary_3 = {"key1: 10,20,30"}

# %%
my_dictionary_3 ["key1"]

# %%
my_dictionary_3 [20]

# %%
my_dictionary_4 = {"key1": 100, "key2": [10,20,30], "key3": {"a":5}}

# %%
my_dictionary_4

# %%
my_dictionary_4.keys()

# %%
my_dictionary_4.values()

# %%
my_dictionary_4["keys3"]["a"]

# %%
my_dictionary_5 = {"key1": 1, "key2": 2}

# %%
my_dictionary_5["k1"] = 3

# %%
my_dictionary_5["k5"] = 7

# %%
my_dictionary_5
