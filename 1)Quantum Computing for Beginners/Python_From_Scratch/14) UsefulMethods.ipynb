# %%
my_list = [1,2,3,4,5,6,7]

# %%
for number in my_list:
    print(number)

# %% [markdown]
# RANGE

# %%
range(20)

# %%
list(range(20))

# %%
for number in list (range(20)):
    print(number * 5 )

# %%
for num in list(range (5,21,4)):
    print(num)

# %% [markdown]
# ENUMARATE

# %%
index = 0
for number in list (rane(5,15)):
    print(f"no: {number} ix: {index}")
    index += 1

# %%
for element in enumarate(list(range(5,15))):
    print(element)

# %%
for (index, number) in enumerate(list(range(5,15))):
    print(index)
    print(number)

# %% [markdown]
# RANDOM

# %%
from random import randint

# %%
randint(0,1000)

# %%
randint(0,1000)

# %%
my_list_2 = list(range(0,10))

# %%
my_list_2

# %%
from random import shuffle

# %%
shuffle(my_list_2)

# %%
my_list_2

# %% [markdown]
# ZIP

# %%
sport_list = ["run", "swim", "basketball"]

# %%
calories_list = [100,200,300]

# %%
day_list = ["monday","tuesday","wednesday"]

# %%
new_list = list(zip(sport_list,calories_list,day_list))

# %%
new_list

# %%
for element in list:
    print(element)

# %% [markdown]
# List Advanced

# %%
new_list = []
my_string = "metallica"

for element in my_string:
    new_list.append(element)

# %%
new_list

# %%
new_list = [element for element in my_string]

# %%
new_list

# %%
new_list_2 = [number**5 for number in list (range(0,10))]

# %%
new_list_2
