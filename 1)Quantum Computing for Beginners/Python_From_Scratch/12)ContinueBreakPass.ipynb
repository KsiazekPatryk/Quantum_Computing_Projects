# %%
my_list = [10,20,30,40,50,60]

# %%
for number in my_list:
    print(number * 5)

# %%
for num in my_list:
    if num == 30:
        break
    print(num * 5)

# %%
for num in my_list:
    if num == 30:
        break
    print(num * 5)

# %%
for item in my_list:
    if item == 30:
        continue
    print( item * 5)

# %%
for no in my_list:
    pass
