# %%
my_list = ["a", 1 , "c"]

# %%
my_list [0] = "b"

# %%
my_list

# %%
my_tuple = ("a", 1 , "c ")

# %%
my_tuple[0]

# %%
#my_tuple'[0] = 'b'

# %% [markdown]
# Immutable

# %%
#my_tuple[1] = 2

# %%
my_tuple.count("a")

# %%
my_tuple_2 = (1,1,1,"a","c")

# %%
my_tuple_2.count(1)

# %%
my_tuple_2.index("a")

# %%
my_tuple_2.index(1)
