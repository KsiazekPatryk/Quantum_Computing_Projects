# %%
True

# %%
False

# %%
my_boolean = True

# %%
is_dead = False

# %%
5 > 3

# %%
5 + 3

# %%
3 > 5

# %%
x = 5

# %%
y = input("y:")

# %%
type(y)

# %%
y_int = int(y)

# %%
type(y_int)

# %%
y_int

# %%
y_int > x
