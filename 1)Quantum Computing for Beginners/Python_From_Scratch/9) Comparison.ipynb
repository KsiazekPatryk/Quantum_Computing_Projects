# %%
x = 5

# %%
y = 4

# %%
x > y

# %%
x < y

# %%
x >= y

# %%
x >= 5

# %%
x>=5.0

# %%
x>=5.1

# %%
x = y

# %%
x

# %%
y

# %%
x=5

# %%
x == y

# %%
x != y

# %%
2 > 1  and 3 > 2

# %%
2 < 1 and 3 > 2

# %%
2 < 1 or 3 > 2

# %%
not 10 == 10
