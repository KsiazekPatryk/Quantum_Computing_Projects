# %%
my_string = "Patryk"

# %%
my_string[0]

# %%
my_string[1]

# %%
#my_string[0] = "B"

# %% [markdown]
# Immutability

# %%
#my_string[2] = "G"

# %%
my_list = [1,2,3]

# %%
my_list[0]

# %%
my_list[0] = 5

# %%
my_list

# %% [markdown]
# Mutable

# %%
my_list[2] = 6

# %%
my_list

# %%
my_list.append(7)

# %%
my_list

# %%
my_string = "lars"

# %%
my_string.capitalize()

# %%
my_string

# %%
my_list

# %%
my_list.pop()

# %%
my_list

# %%
my_mixed_list = [1,2,"a","bhf"]

# %%
my_mixed_list [0]

# %%
my_mixed_list[0]

# %%
my_mixed_list[-1]

# %%
my_list_1 = ["a","b","c"]

# %%
my_list_2 = ["d","e","f"]

# %%
my_list_3 = my_list_1 + my_list_2

# %%
my_list_3

# %%
my_list_1 * 3

# %%
my_list_1.reverse()

# %%
my_list_1

# %% [markdown]
# Nested List

# %%
new_list = [1,4, "a"]

# %%
new_list = [1,4,"a", [3, "c"]]

# %%
new_list[2]

# %%
new_list[3]

# %%
nested_list = new_list[3]

# %%
nested_list

# %%
nested_list[1]

# %%
new_list[3][1]

# %%
new_list

# %%
new_list[2:]

# %%
new_list[:2]
