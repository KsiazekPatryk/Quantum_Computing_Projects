# %%
def summartion(num1,num2):
    return num1 + num2

# %%
x = input ("Enter number:")

# %%
y = input ("Enter number:")

# %%
def numberpower(num1):
    return num1 ** 2

# %% [markdown]
# try,except, finally

# %%
while True:
    try:
        my_int = int(input("Enter a number: "))
    except:
        print("Enter a number!!!")
        continue
    else:
        print("OK")
        break
    finally:
        print("finally")
