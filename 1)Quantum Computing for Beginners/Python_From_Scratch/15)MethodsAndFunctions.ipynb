# %%
my_string = "Atil"

# %%
my_string_upper = my_string_upper()

# %%
my_string

# %%
my_string_upper

# %%
help(my_string.split)

# %%
def hello_world():
    print("hello")
    print("world")

# %%
hello_world

# %%
hello_world

# %% [markdown]
# Input & Return

# %%
def hello_programming(name):
    print(hello)
    print(name)

# %%
hello_programming("Python")

# %%
hello_programming("Java")

# %%
def hello_program(name="Python"):
    print("hello")
    print(name)

# %%
hello_program()

# %%
hello_program("Java")

# %%
def sum(number1, number2):
    number3 = number1 + number2
    print(number3)

# %%
sum(5,8)

# %%
sum(10,-500)

# %%
def summaration(num1,num2,num3):
    return num1+num2+num3

# %%
summaration(10,20,30)

# %%
my_result = summaration (10,20,30)

# %%
my_result

# %%
my_integer = summ(10,20)

# %%
my_integer

# %%
type(my_integer)

# %%
def control_string(s):
    if s [0] == "m":
        print("mmm")

# %%
control_string("paris")

# %%
control_string("metallica")

# %%
def control_string(s):
    if s[0] == "m":
        print(s.capitalize())

# %%
control_string("metallica")

# %%
control_string("amsterdam")

# %% [markdown]
# Arbitrary Arguments & Key Word Arguments

# %%
def summartion_2(*args):
    return sum(args)

# %%
summartion_2(10,20,30)

# %%
summartion_2(50,60,70,80)

# %%
def my_func(*args):
    print(args)

# %%
my_func("a","b",1,2)

# %%
#def my_func_2(*atil):
#   print(atil)

# %%
#my_func_2("at", "il", 1,2,3)

# %%
def example_func(**kwargs):
    print(kwargs)

# %%
example_func(run=100,swim=200,basketball=300)

# %%
example_func(a=1, b=2)

# %%
def keyword_func(**kwargs):
    if "Metallica" in kwargs:
        print("Heavy Metalll!")
    else:
        print("Rock is dead!!!")

# %%
keyword_func(Metallica=10, Madonna=5, Muslum=4)

# %%
keyword_func(Madonna=8, Mickey=4)
