# %%
"Hello World"

# %%
'Hello'

# %%
'I am a pilot'

# %%
x = 'hello world'

# %%
x = 'hello'

# %%
x = '3'

# %%
x = "hello world"

# %%
type(x)

# %%
len(x)

# %% [markdown]
# Length

# %%
len(x)

# %%
print(x)

# %% [markdown]
# Escape Characters

# %%
print("Hello Python")

# %%
print("Hello \npython")

# %%
print("Hello \tpython")
