# %%
my_list = [1,2,3,1]

# %%
my_list

# %% [markdown]
# Casting

# %%
my_set = set(my_list)

# %%
my_set

# %%
my_set_2 = {1,2,3,1}

# %%
my_set_2

# %%
type(my_set_2)

# %%
my_set_3 = {"a", "b", "a"}

# %%
my_set_3

# %%
my_list = []

# %%
type(my_list)

# %%
my_list

# %%
my_list.append(1)

# %%
my_list

# %%
my_set_4 = {}

# %%
my_set_4

# %%
type(my_set_4)

# %%
my_set_4["key1"] = 1

# %%
my_set_4

# %%
my_set_5 = set()

# %%
my_set_5

# %%
my_set_5.add(1)

# %%
my_set_5.add(2)

# %%
my_set_5

# %%
type(my_set_5)

# %%
my_dict_2 = dict()

# %%
my_dict_2["key1"] = 1

# %%
my_dict_2

# %%
my_list_10 = list()

# %%
type(my_list_10)

# %%
my_list_10

# %%
my_list_10.append(a)

# %%
my_list_10.append(2)

# %%
my_list_10.append([1,2])

# %%
my_list_10
